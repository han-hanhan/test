# %%
l = []
for i in range(1,46):
    for j in range(1,13):
        l.append(i*j)
l.sort()
print(l[470])
print(l.count(312))
print(311 in l)
# Out:
# 312
# 2
# False

# %%
import bisect
print(bisect.bisect_left([1,2,3],4))
# Out:
# 3

# %%
l = [1,2,3]
l.reverse()
print(l)
print(sorted('dcba'),type(sorted('dcba')))
# Out:
# [3, 2, 1]
# ['a', 'b', 'c', 'd'] <class 'list'>
